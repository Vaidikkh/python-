# %%
import numpy as np

# %%
print("list convert into array:")
lst = [1,2,3,4,5,6,7,8,9]
print("This is my list",lst)
print("Type of list",type(lst))
print("List convert into array")
arr = np.array(list)
print(arr)
# Out:
# list convert into array:
# This is my list [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Type of list <class 'list'>
# List convert into array
# <class 'list'>

# %%
arr = np.arange(6)
arr = arr.reshape(12,5)
arr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 arr = np.arange(6)
# ----> 2 arr = arr.reshape(12,5)
#       3 arr
#
# ValueError: cannot reshape array of size 6 into shape (12,5)
