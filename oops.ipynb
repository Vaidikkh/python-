# %%
# Class
class ClassName:
    pass #Class name should be always capital

# %%
class College:
    pass
# class as key
# college >> class name
# pass as a place holder

# %%
class College:
    pass
clg = College()
clg2 = College()

# %%
class College:
    College_name = "Anand ICE"
    College_address = "Kanota Jaipur"
    College_sp = 52            # class variable

clg = College()
#clg ia a object

print(clg.College_sp)
print(clg.College_address)
print(clg.College_name)

student = College()   # New object
print(student.College_sp)
print(student.College_address)
print(student.College_name)
# Out:
# 52
# Kanota Jaipur
# Anand ICE
# 52
# Kanota Jaipur
# Anand ICE

# %%
# method

class College:
    College_name = "Anand ICE"
    College_address = "Kanota Jaipur"
    College_sp = 52            # class variable

    def display(self):
        pass
student = College()
student.display()

# %%
# method

class College:
    College_name = "Anand ICE"
    College_address = "Kanota Jaipur"
    College_sp = 52            # class variable

    def display(self, a, b):
        print(a,b)
student = College()
student.display(11,3)
# Out:
# 11 3

# %%
# method

class College:
    College_name = "Anand ICE"
    College_address = "Kanota Jaipur"
    College_sp = 52            # class variable

    def display(self):

        print(self.College_name)
        print(self.College_address)
        print(self.College_sp)
        # pass
student = College()

# %%
student.display()
# Out:
# Anand ICE
# Kanota Jaipur
# 52

# %%
# Encapsulation
class College:
    college_name= "Anand ICE"
    college_library = "ANAND LIBRARY"
    _college_account = 4655345644



student

# %%
class a:
    _a=10
class b(a):
    pass

l=b()
l._a
# Out:
# 10
