# %% [markdown]
# 1. Find the largest, smallest, and second largest number from 10 user
# inputs.

# %%
numbers = []
for i in range(0,10):
    num =int(input(f"enter number {i}:", ))
    print(num)
    numbers.append(num)

largest = max(numbers)
smallest = min(numbers)
# Out:
# 5
# 6
# 2
# 9
# 4
# 2
# 825
# 5
# 6
# 2
