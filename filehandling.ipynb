# %%
file = open("new.txt",'a')
file.write("My name is Vaidik")
file.close()

# %%
file = open("new.txt",'r')
print(file.read())
file.close()
# Out:
# My name is Vaidik

# %%
file = open("new.txt",'a')
file.write("\tMy name is Vaidik")
file.close()

# %%
file = open("new.txt",'r')
print(file.read())
file.close()
# Out:
# My name is Vaidik
# My name is Vaidik	My name is Vaidik

# %%
file= open("vkk.txt",'x')

file.close()

# %%
import os
os.remove("vkk.txt")
